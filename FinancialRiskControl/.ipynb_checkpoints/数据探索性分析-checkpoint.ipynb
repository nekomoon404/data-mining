# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression as LR

# %% [markdown]
# 1.读取文件

# %%
data_train = pd.read_csv(r"F:\CodeApplication\Jupyter\Datawhale\train.csv")

# %%
data_test_a = pd.read_csv(r"F:\CodeApplication\Jupyter\Datawhale\testA.csv")

# %%
data_train.head()
# Out:
#    id  loanAmnt  term  interestRate  installment grade subGrade  \
# 0   0   35000.0     5         19.52       917.97     E       E2
# 1   1   18000.0     5         18.49       461.90     D       D2
# 2   2   12000.0     5         16.99       298.17     D       D3
# 3   3   11000.0     3          7.26       340.96     A       A4
# 4   4    3000.0     3         12.99       101.07     C       C2
#
#    employmentTitle employmentLength  homeOwnership  ...    n5    n6    n7  \
# 0            320.0          2 years              2  ...   9.0   8.0   4.0
# 1         219843.0          5 years              0  ...   NaN   NaN   NaN
# 2          31698.0          8 years              0  ...   0.0  21.0   4.0
# 3          46854.0        10+ years              1  ...  16.0   4.0   7.0
# 4             54.0              NaN              1  ...   4.0   9.0  10.0
#
#      n8   n9   n10  n11  n12  n13  n14
# 0  12.0  2.0   7.0  0.0  0.0  0.0  2.0
# 1   NaN  NaN  13.0  NaN  NaN  NaN  NaN
# ...

# %%
data_train.shape
# Out:
# (800000, 47)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 47 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  800000 non-null  int64
#  1   loanAmnt            800000 non-null  float64
#  2   term                800000 non-null  int64
#  3   interestRate        800000 non-null  float64
#  4   installment         800000 non-null  float64
#  5   grade               800000 non-null  object
#  6   subGrade            800000 non-null  object
#  7   employmentTitle     799999 non-null  float64
#  8   employmentLength    753201 non-null  object
#  9   homeOwnership       800000 non-null  int64
#  10  annualIncome        800000 non-null  float64
#  11  verificationStatus  800000 non-null  int64
#  12  issueDate           800000 non-null  object
#  13  isDefault           800000 non-null  int64
#  14  purpose             800000 non-null  int64
# ...

# %% [markdown]
# 2.粗略地查看数据集各个特征的一些基本统计量

# %%
data_train.describe()
# Out:
#                   id       loanAmnt           term   interestRate  \
# count  800000.000000  800000.000000  800000.000000  800000.000000
# mean   399999.500000   14416.818875       3.482745      13.238391
# std    230940.252013    8716.086178       0.855832       4.765757
# min         0.000000     500.000000       3.000000       5.310000
# 25%    199999.750000    8000.000000       3.000000       9.750000
# 50%    399999.500000   12000.000000       3.000000      12.740000
# 75%    599999.250000   20000.000000       3.000000      15.990000
# max    799999.000000   40000.000000       5.000000      30.990000
#
#          installment  employmentTitle  homeOwnership  annualIncome  \
# count  800000.000000    799999.000000  800000.000000  8.000000e+05
# mean      437.947723     72005.351714       0.614213  7.613391e+04
# std       261.460393    106585.640204       0.675749  6.894751e+04
# min        15.690000         0.000000       0.000000  0.000000e+00
# ...

# %%
#检查下有没有重复值，结果是没有
#data_train.drop_duplicates(inplace = True)
#data_train.info()

# %% [markdown]
# 3.查看缺失值

# %%
print(f'There are {data_train.isnull().any().sum()} columns in train dataset with missing values.')
# Out:
# There are 22 columns in train dataset with missing values.

# %% [markdown]
# 上面得到训练集有22列特征有缺失值，进一步查看缺失特征中缺失率大于50%的特征，从上面的data_train.info()也可以知道没有缺失率大于50%的特征

# %%
have_null_fea_dict = (data_train.isnull().sum() / len(data_train)).to_dict()
fea_null_moreThanHalf = {}
for key, value in have_null_fea_dict.items():
    if value > 0.5:
        fea_null_moreThanHalf[key] = value

fea_null_moreThanHalf
# Out:
# {}

# %% [markdown]
# 具体地查看缺失特征及缺失率。如果nan存在的过多（多少比例算多？），说明这一列对label的影响几乎不起作用，可以考虑删掉；如果缺失值很小一般可以选择填充。

# %%
#nan可视化

missing = data_train.isnull().sum() / len(data_train)
missing = missing[missing > 0]
missing.sort_values(inplace = True)
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 4.查看训练集测试集中特征属性只有一值的特征

# %%
one_value_fea = [col for col in data_train.columns if data_train[col].nunique() <= 1]
one_value_fea_test = [col for col in data_test_a.columns if data_test_a[col].nunique() <= 1]

print(one_value_fea)
print(one_value_fea_test)
# Out:
# ['policyCode']
# ['policyCode']

# %% [markdown]
# 'policyCode'这一特征具有唯一值：1，可以删掉

# %% [markdown]
# 5.查看特征的数值类型有哪些，对象类型有哪些
# * 特征一般都是由类别特征和数值特征组成，而数值特征又分为连续型和离散型
# * 类别型特征一般有三种：
#  1. 特征的几种取值是相互独立的，彼此之间完全没有联系，这是**名义变量**。可以使用哑变量的方式来处理。`preprocessing.OneHotEncoder`
#  2. 特征的几种取值不是完全独立的，如学历（小学，初中，高中），在性质上有高中>初中>小学这样的联系，但是学历取值之间却是不能计算的，这是**有序变量**。可以用OridinalEncoder来处理。`preprocessing.OridinalEncoder`：特征专用，能够将分类特征转换为分类数值。
#  3. 特征的几种取值间有联系，且可以相互计算，如体重（>45kg, >90kg, >100kg），这是**有距变量**。可以用OridinalEncoder来处理。
# * 数值特征本是可以直接入职的，但风控人员要对其做分箱。（可参考菜菜机器学习 05.3：用逻辑回归制作评分卡）

# %%
numerical_fea = list(data_train.select_dtypes(exclude=['object']).columns)
category_fea = list(filter(lambda x : x not in numerical_fea, list(data_train.columns)))

# %%
numerical_fea    #数值类型的特征
# Out:
# ['id',
#  'loanAmnt',
#  'term',
#  'interestRate',
#  'installment',
#  'employmentTitle',
#  'homeOwnership',
#  'annualIncome',
#  'verificationStatus',
#  'isDefault',
#  'purpose',
#  'postCode',
#  'regionCode',
#  'dti',
#  'delinquency_2years',
#  'ficoRangeLow',
#  'ficoRangeHigh',
#  'openAcc',
#  'pubRec',
#  'pubRecBankruptcies',
#  'revolBal',
#  'revolUtil',
#  'totalAcc',
#  'initialListStatus',
#  'applicationType',
#  'title',
#  'policyCode',
#  'n0',
#  'n1',
#  'n2',
#  'n2.1',
#  'n4',
#  'n5',
#  'n6',
#  'n7',
#  'n8',
#  'n9',
#  'n10',
#  'n11',
#  'n12',
#  'n13',
#  'n14']

# %%
category_fea   #类别类型的特征
# Out:
# ['grade', 'subGrade', 'employmentLength', 'issueDate', 'earliesCreditLine']

# %% [markdown]
# 6.数值型变量分析，数值型肯定是包括连续型变量和离散型变量，需要划分出数值型变量中的连续变量和分类变量

# %%
def get_numerical_serial_fea(data, feas):
    numerical_serial_fea = []
    numerical_noserial_fea = []
    for fea in feas:
        temp = data[fea].nunique()
        if temp <= 10:
            numerical_noserial_fea.append(fea)
            continue
        numerical_serial_fea.append(fea)
    return numerical_serial_fea, numerical_noserial_fea
numerical_serial_fea, numerical_noserial_fea = get_numerical_serial_fea(data_train, numerical_fea)

# %%
numerical_serial_fea   #连续型变量
# Out:
# ['id',
#  'loanAmnt',
#  'interestRate',
#  'installment',
#  'employmentTitle',
#  'annualIncome',
#  'purpose',
#  'postCode',
#  'regionCode',
#  'dti',
#  'delinquency_2years',
#  'ficoRangeLow',
#  'ficoRangeHigh',
#  'openAcc',
#  'pubRec',
#  'pubRecBankruptcies',
#  'revolBal',
#  'revolUtil',
#  'totalAcc',
#  'title',
#  'n0',
#  'n1',
#  'n2',
#  'n2.1',
#  'n4',
#  'n5',
#  'n6',
#  'n7',
#  'n8',
#  'n9',
#  'n10',
#  'n13',
#  'n14']

# %%
numerical_noserial_fea   #离散型变量
# Out:
# ['term',
#  'homeOwnership',
#  'verificationStatus',
#  'isDefault',
#  'initialListStatus',
#  'applicationType',
#  'policyCode',
#  'n11',
#  'n12']

# %% [markdown]
# 6.1.数值离散型变量型分析

# %%
data_train['term'].value_counts()   #离散型变量，term - 贷款期限（year）
# Out:
# 3    606902
# 5    193098
# Name: term, dtype: int64

# %%
data_train['homeOwnership'].value_counts()   #离散型变量，homeOwnership - 借款人在登记时提供的房屋所有权状况
# Out:
# 0    395732
# 1    317660
# 2     86309
# 3       185
# 5        81
# 4        33
# Name: homeOwnership, dtype: int64

# %%
data_train['verificationStatus'].value_counts()   #离散型变量，verificationStatus - 验证状态
# Out:
# 1    309810
# 2    248968
# 0    241222
# Name: verificationStatus, dtype: int64

# %%
data_train['initialListStatus'].value_counts()   #离散型变量，initialListStatus - 贷款的初始列表状态
# Out:
# 0    466438
# 1    333562
# Name: initialListStatus, dtype: int64

# %%
data_train['applicationType'].value_counts()   #离散型变量，applicationType - 表明贷款人是个人申请还是与两个共同借款人（估计是1）的联合申请
# Out:
# 0    784586
# 1     15414
# Name: applicationType, dtype: int64

# %%
data_train['policyCode'].value_counts()   #离散型变量，无用
# Out:
# 1.0    800000
# Name: policyCode, dtype: int64

# %%
data_train['n11'].value_counts()   #离散型变量，相差悬殊
# Out:
# 0.0    729682
# 1.0       540
# 2.0        24
# 4.0         1
# 3.0         1
# Name: n11, dtype: int64

# %%
data_train['n12'].value_counts()   #离散型变量，相差悬殊
# Out:
# 0.0    757315
# 1.0      2281
# 2.0       115
# 3.0        16
# 4.0         3
# Name: n12, dtype: int64

# %% [markdown]
# 6.2.数值连续型变量分析

# %% [markdown]
# `sns.distplot()`，查看单元分布的函数.该函数默认绘制直方图并拟合内核密度估计。通过调整参数可以分别绘制直方图，拟合内核密度图，地毯图等。

# %%
#每个数字特征的分布可视化
import seaborn as sns

f = pd.melt(data_train, value_vars = numerical_serial_fea)
g = sns.FacetGrid(f, col = "variable", col_wrap = 2, sharex = False, sharey = False)
g = g.map(sns.distplot, "value")

# %% [markdown]
# * 查看某一数值型变量的分布，查看变量是否符合正态分布（如何检查，`scipy.stats.normaltest`？），如果不符合正态分布的变量可以log化后再观察下是否符合正态分布。
# * 一些情况下正态可以让模型更快的收敛，一些模型要求数据正态（eg.GMM、KNN），保证数据不要过偏态，过于偏态可能会影响模型预测结果。
# * 如果想统一处理一批数据变标准化，必须要这些之前已经正态化的数据提出。

# %%
#Ploting Transaction Amount Values Distribution
import matplotlib.pyplot as plt

plt.figure(figsize=(16,12))
plt.suptitle('Transaction Values Distribution', fontsize=22)
plt.subplot(221)
sub_plot_1 = sns.distplot(data_train['loanAmnt'])
sub_plot_1.set_title("loanAmnt Distribuition", fontsize=18)
sub_plot_1.set_xlabel("")
sub_plot_1.set_ylabel("Probability", fontsize=15)

plt.subplot(222)
sub_plot_2 = sns.distplot(np.log(data_train['loanAmnt']))
sub_plot_2.set_title("loanAmnt (Log) Distribuition", fontsize=18)
sub_plot_2.set_xlabel("")
sub_plot_2.set_ylabel("Probability", fontsize=15)
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# 6.3.非数值类型变量分析

# %%
category_fea
# Out:
# ['grade', 'subGrade', 'employmentLength', 'issueDate', 'earliesCreditLine']

# %%
data_train['grade'].value_counts()
# Out:
# B    233690
# C    227118
# A    139661
# D    119453
# E     55661
# F     19053
# G      5364
# Name: grade, dtype: int64

# %%
data_train['subGrade'].value_counts()   #每个grade下面有5个subGrdde
# Out:
# C1    50763
# B4    49516
# B5    48965
# B3    48600
# C2    47068
# C3    44751
# C4    44272
# B2    44227
# B1    42382
# C5    40264
# A5    38045
# A4    30928
# D1    30538
# D2    26528
# A1    25909
# D3    23410
# A3    22655
# A2    22124
# D4    21139
# D5    17838
# E1    14064
# E2    12746
# E3    10925
# E4     9273
# E5     8653
# F1     5925
# F2     4340
# F3     3577
# F4     2859
# F5     2352
# G1     1759
# G2     1231
# G3      978
# G4      751
# G5      645
# Name: subGrade, dtype: int64

# %%
data_train['employmentLength'].value_counts()   #每个grade下面有5个subGrdde
# Out:
# 10+ years    262753
# 2 years       72358
# < 1 year      64237
# 3 years       64152
# 1 year        52489
# 5 years       50102
# 4 years       47985
# 6 years       37254
# 8 years       36192
# 7 years       35407
# 9 years       30272
# Name: employmentLength, dtype: int64

# %%
data_train['issueDate'].value_counts()
# Out:
# 2016-03-01    29066
# 2015-10-01    25525
# 2015-07-01    24496
# 2015-12-01    23245
# 2014-10-01    21461
#               ...
# 2007-08-01       23
# 2007-07-01       21
# 2008-09-01       19
# 2007-09-01        7
# 2007-06-01        1
# Name: issueDate, Length: 139, dtype: int64

# %%
data_train['earliesCreditLine'].value_counts()
# Out:
# Aug-2001    5567
# Aug-2002    5403
# Sep-2003    5403
# Oct-2001    5258
# Aug-2000    5246
#             ...
# Sep-1953       1
# Sep-1957       1
# Aug-1955       1
# Oct-1957       1
# Nov-1953       1
# Name: earliesCreditLine, Length: 720, dtype: int64

# %%
data_train['isDefault'].value_counts()   #label，违约为1
# Out:
# 0    640390
# 1    159610
# Name: isDefault, dtype: int64

# %% [markdown]
# 7.变量分布可视化

# %% [markdown]
# 7.1.单一变量分布可视化

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 8))
sns.barplot(data_train["employmentLength"].value_counts(dropna = False)[:20],
            data_train["employmentLength"].value_counts(dropna = False).keys()[:20])
plt.show()

# %% [markdown]
# 7.2.根据y值不同可视化x某个特征的分布
#
# 首先查看类别型变量在不同y值上的分布

# %%
train_loan_fr = data_train.loc[data_train['isDefault'] == 1]   #违约
train_loan_nofr = data_train.loc[data_train['isDefault'] == 0]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (15, 8))
train_loan_fr.groupby('grade')['grade'].count().plot(kind = 'barh', ax = ax1, title = 'Count of grade fraud')     #在违约的人中特征grade的分布
train_loan_nofr.groupby('grade')['grade'].count().plot(kind = 'barh', ax = ax2, title = 'Count of grade non-fraud')

train_loan_fr.groupby('employmentLength')['employmentLength'].count().plot(kind = 'barh', ax = ax3, title = 'Count of employmentLength fraud')
train_loan_nofr.groupby('employmentLength')['employmentLength'].count().plot(kind = 'barh', ax = ax4, title = 'Count of employmentLength non-fraud')
# Out:
# <AxesSubplot:title={'center':'Count of employmentLength non-fraud'}, ylabel='employmentLength'>

# %% [markdown]
# 查看连续型变量在不同y值上的分布

# %%
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize = (15, 6))
data_train.loc[data_train['isDefault'] == 1]['loanAmnt'].apply(np.log).plot(kind = 'hist',
                                                                            bins = 100,
                                                                            title = 'Log Loan Amt - Fraud',
                                                                            color = 'r',
                                                                            xlim = (-3, 10),
                                                                            ax = ax1)              #在违约的人中特征 log(loanAmt)的分布
data_train.loc[data_train['isDefault'] == 0]['loanAmnt'].apply(np.log).plot(kind = 'hist',
                                                                            bins = 100,
                                                                            title = 'Log Loan Amt - Not Fraud',
                                                                            color = 'b',
                                                                            xlim = (-3, 10),
                                                                            ax = ax2)
# Out:
# <AxesSubplot:title={'center':'Log Loan Amt - Not Fraud'}, ylabel='Frequency'>

# %%
total = len(data_train)
total_amt = data_train.groupby(['isDefault'])['loanAmnt'].sum().sum()
plt.figure(figsize = (12, 5))
plt.subplot(121)
plot_tr = sns.countplot(x = 'isDefault', data = data_train)
plot_tr.set_title("Fraud Loan Distribution \n 0: good user | 1: bad user", fontsize = 14)
plot_tr.set_xlabel("Is fraud by count", fontsize = 16)
plot_tr.set_ylabel('Count', fontsize = 16)
for p in plot_tr.patches:
    height = p.get_height()
    plot_tr.text(p.get_x() + p.get_width() / 2.,
                 height + 3,
                 '{:1.2f}%'.format(height / total * 100 ),
                 ha = 'center', fontsize = 15)

#统计贷款总金额中，违约的金额和没违约的金额的所占的比例？    
percent_amt = (data_train.groupby(['isDefault'])['loanAmnt'].sum())
percent_amt = percent_amt.reset_index()
plt.subplot(122)
plot_tr_2 = sns.barplot(x = 'isDefault', y = 'loanAmnt', dodge = True, data = percent_amt)
plot_tr_2.set_title("Total Amount in loanAmnt \n 0: good user | 1: bad user", fontsize = 14)
plot_tr_2.set_xlabel("Is fraud by percent", fontsize = 16)
plot_tr_2.set_ylabel('Total Loan Amount Scalar', fontsize = 16)
for p in plot_tr_2.patches:
    height = p.get_height()
    plot_tr_2.text(p.get_x() + p.get_width() / 2.,
                 height + 3,
                 '{:1.2f}%'.format(height / total_amt * 100 ),
                 ha = 'center', fontsize = 15)

# %% [markdown]
# 8.时间格式数据处理及查看

# %%
#转化成时间格式
import datetime

data_train['issueDate'] = pd.to_datetime(data_train['issueDate'], format = '%Y-%m-%d')
startdate = datetime.datetime.strptime('2007-06-01', '%Y-%m-%d')
data_train['issueDateDT'] = data_train['issueDate'].apply(lambda x: x-startdate).dt.days

# %%
data_test_a['issueDate'] = pd.to_datetime(data_test_a['issueDate'], format = '%Y-%m-%d')
startdate = datetime.datetime.strptime('2007-06-01', '%Y-%m-%d')
data_test_a['issueDateDT'] = data_test_a['issueDate'].apply(lambda x: x-startdate).dt.days

# %%
plt.hist(data_train['issueDateDT'], label = 'train')
plt.hist(data_test_a['issueDateDT'], label = 'test')
plt.legend()
plt.title('Distribution of issueDateDT dates')

#train和test issueDateDT 日期有重叠，所以使用基于时间的分割进行验证是不明智的（什么是基于时间的分割）
# Out:
# Text(0.5, 1.0, 'Distribution of issueDateDT dates')

# %% [markdown]
# 9.用pandas_profiling 生成数据报告（需要低版本的pandas）

# %%
import pandas_profiling
pfr = pandas_profiling.ProfileReport(data_train)
pfr.to_file("./example.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-c6ca5df4d0bf> in <module>
#       2
#       3 import pandas_profiling
# ----> 4 pfr = pandas_profiling.ProfileReport(data_train)
#       5 pfr.to_file("./example.html")
#
# F:\Application\Anaconda3\envs\sklearn\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# F:\Application\Anaconda3\envs\sklearn\lib\site-packages\pandas_profiling\describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# ...
